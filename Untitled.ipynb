# %%
import pandas as pd

# %%
a = pd.read_csv('sheet.csv')
a
# Out:
#       Name  Hindi English Maths Sciennce  Computer
# 0  Manisha     91      64    95       43        50
# 1  Seema..     93      38   NaN       71        46
# 2   Mukesh     85      fg    93       gh        75
# 3  ..Rahul     89      45    44       98        77
# 4     Aman     89     NaN    47       64        59
# 5     Raja     64      61    gh       50        92
# 6     Raja     64      61    gh       50        92

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      7 non-null      object
#  1   Hindi     7 non-null      int64
#  2   English   6 non-null      object
#  3   Maths     6 non-null      object
#  4   Sciennce  7 non-null      object
#  5   Computer  7 non-null      int64
# dtypes: int64(2), object(4)
# memory usage: 468.0+ bytes

# %%
#find duplicate value

# %%
a.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# dtype: bool

# %%
#remove Duplicate

# %%
a.drop_duplicates(inplace = True)
a
# Out:
#       Name  Hindi English Maths Sciennce  Computer
# 0  Manisha     91      64    95       43        50
# 1  Seema..     93      38   NaN       71        46
# 2   Mukesh     85      fg    93       gh        75
# 3  ..Rahul     89      45    44       98        77
# 4     Aman     89     NaN    47       64        59
# 5     Raja     64      61    gh       50        92

# %%
#remove mistekes

# %%
a['Name'].str.rstrip('..')
# Out:
# 0    Manisha
# 1      Seema
# 2     Mukesh
# 3    ..Rahul
# 4       Aman
# 5       Raja
# Name: Name, dtype: object

# %%
a['Name'].str.lstrip('..')
# Out:
# 0    Manisha
# 1    Seema..
# 2     Mukesh
# 3      Rahul
# 4       Aman
# 5       Raja
# Name: Name, dtype: object

# %%
a['Name'].str.strip('..')
# Out:
# 0    Manisha
# 1      Seema
# 2     Mukesh
# 3      Rahul
# 4       Aman
# 5       Raja
# Name: Name, dtype: object

# %%
#find null and missing value

# %%
a.isnull()
# Out:
#     Name  Hindi  English  Maths  Sciennce  Computer
# 0  False  False    False  False     False     False
# 1  False  False    False   True     False     False
# 2  False  False    False  False     False     False
# 3  False  False    False  False     False     False
# 4  False  False     True  False     False     False
# 5  False  False    False  False     False     False

# %%
#column with NAN usinng integer
a.isnull().sum()
# Out:
# Name        0
# Hindi       0
# English     1
# Maths       1
# Sciennce    0
# Computer    0
# dtype: int64

# %%
#column with NAN using true false
a.isnull().any()
# Out:
# Name        False
# Hindi       False
# English      True
# Maths        True
# Sciennce    False
# Computer    False
# dtype: bool

# %%
#Total no of messing NAN value
a.isnull().sum().sum()
# Out:
# 2

# %%
#change column name

# %%
a.rename(columns = {'Name' : 'Students'}, inplace = True)
a
# Out:
#   Students  Hindi English Maths Sciennce  Computer
# 0  Manisha     91      64    95       43        50
# 1  Seema..     93      38   NaN       71        46
# 2   Mukesh     85      fg    93       gh        75
# 3  ..Rahul     89      45    44       98        77
# 4     Aman     89     NaN    47       64        59
# 5     Raja     64      61    gh       50        92

# %%
a['Total'] = 0
a
# Out:
#   Students  Hindi English Maths Sciennce  Computer  Total
# 0  Manisha     91      64    95       43        50      0
# 1  Seema..     93      38   NaN       71        46      0
# 2   Mukesh     85      fg    93       gh        75      0
# 3  ..Rahul     89      45    44       98        77      0
# 4     Aman     89     NaN    47       64        59      0
# 5     Raja     64      61    gh       50        92      0

# %%
a['Total'] = a['Hindi']+a['Computer']
a
# Out:
#   Students  Hindi English Maths Sciennce  Computer  Total
# 0  Manisha     91      64    95       43        50    141
# 1  Seema..     93      38   NaN       71        46    139
# 2   Mukesh     85      fg    93       gh        75    160
# 3  ..Rahul     89      45    44       98        77    166
# 4     Aman     89     NaN    47       64        59    148
# 5     Raja     64      61    gh       50        92    156

# %%
a['Total'].max()
# Out:
# 166

# %%
a.describe()
# Out:
#            Hindi   Computer       Total
# count   6.000000   6.000000    6.000000
# mean   85.166667  66.500000  151.666667
# std    10.703582  17.784825   10.782702
# min    64.000000  46.000000  139.000000
# 25%    86.000000  52.250000  142.750000
# 50%    89.000000  67.000000  152.000000
# 75%    90.500000  76.500000  159.000000
# max    93.000000  92.000000  166.000000

# %%
#replace value
a.replace(to_replace =141, value = 999 )
a
# Out:
#   Students  Hindi English Maths Sciennce  Computer  Total
# 0  Manisha     91      64    95       43        50    141
# 1  Seema..     93      38   NaN       71        46    139
# 2   Mukesh     85      fg    93       gh        75    160
# 3  ..Rahul     89      45    44       98        77    166
# 4     Aman     89     NaN    47       64        59    148
# 5     Raja     64      61    gh       50        92    156

# %%
a.replace(to_replace ='Manisha', value = 'Mahi', inplace = True )
a
# Out:
#   Students  Hindi English Maths Sciennce  Computer  Total
# 0     Mahi     91      64    95       43        50    141
# 1  Seema..     93      38   NaN       71        46    139
# 2   Mukesh     85      fg    93       gh        75    160
# 3  ..Rahul     89      45    44       98        77    166
# 4     Aman     89     NaN    47       64        59    148
# 5     Raja     64      61    gh       50        92    156

# %%
a
# Out:
#   Students  Hindi English Maths Sciennce  Computer  Total
# 0     Mahi     91      64    95       43        50    141
# 1  Seema..     93      38   NaN       71        46    139
# 2   Mukesh     85      fg    93       gh        75    160
# 3  ..Rahul     89      45    44       98        77    166
# 4     Aman     89     NaN    47       64        59    148
# 5     Raja     64      61    gh       50        92    156

# %%
a.style.hide(axis = 'index')
# Out:
# <style type="text/css">
# </style>
# <table id="T_0ab62">
#   <thead>
#     <tr>
#       <th id="T_0ab62_level0_col0" class="col_heading level0 col0" >Students</th>
#       <th id="T_0ab62_level0_col1" class="col_heading level0 col1" >Hindi</th>
#       <th id="T_0ab62_level0_col2" class="col_heading level0 col2" >English</th>
#       <th id="T_0ab62_level0_col3" class="col_heading level0 col3" >Maths</th>
#       <th id="T_0ab62_level0_col4" class="col_heading level0 col4" >Sciennce</th>
#       <th id="T_0ab62_level0_col5" class="col_heading level0 col5" >Computer</th>
#       <th id="T_0ab62_level0_col6" class="col_heading level0 col6" >Total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_0ab62_row0_col0" class="data row0 col0" >Mahi</td>
#       <td id="T_0ab62_row0_col1" class="data row0 col1" >91</td>
#       <td id="T_0ab62_row0_col2" class="data row0 col2" >64</td>
#       <td id="T_0ab62_row0_col3" class="data row0 col3" >95</td>
# ...

# %%
a['English'] = a['English'].str.replace("[A-Za-z]","",regex=True)
a
# Out:
#   Students  Hindi English Maths Sciennce  Computer  Total
# 0     Mahi     91      64    95       43        50    141
# 1  Seema..     93      38   NaN       71        46    139
# 2   Mukesh     85            93       gh        75    160
# 3  ..Rahul     89      45    44       98        77    166
# 4     Aman     89     NaN    47       64        59    148
# 5     Raja     64      61    gh       50        92    156

# %%
a['Sciennce'].replace(to_replace='gh',value=80 ,inplace=True)
a
# Out:
#   Students  Hindi English Maths Sciennce  Computer  Total
# 0     Mahi     91      64    95       43        50    141
# 1  Seema..     93      38   NaN       71        46    139
# 2   Mukesh     85            93       80        75    160
# 3  ..Rahul     89      45    44       98        77    166
# 4     Aman     89     NaN    47       64        59    148
# 5     Raja     64      61    gh       50        92    156

# %%
a['English'].replace(to_replace='',value=99,inplace = True)
a
# Out:
#   Students  Hindi English Maths Sciennce  Computer  Total
# 0     Mahi     91      64    95       43        50    141
# 1  Seema..     93      38   NaN       71        46    139
# 2   Mukesh     85      99    93       80        75    160
# 3  ..Rahul     89      45    44       98        77    166
# 4     Aman     89     NaN    47       64        59    148
# 5     Raja     64      61    gh       50        92    156

# %%
a
# Out:
#   Students  Hindi English Maths Sciennce  Computer  Total
# 0     Mahi     91      64    95       43        50    141
# 1  Seema..     93      38   NaN       71        46    139
# 2   Mukesh     85            93       80        75    160
# 3  ..Rahul     89      45    44       98        77    166
# 4     Aman     89     NaN    47       64        59    148
# 5     Raja     64      61    gh       50        92    156
